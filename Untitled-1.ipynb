# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as colors
import matplotlib.axes as ax
import csv
import pandas as pd
import math
import re
from mpl_toolkits.axes_grid1 import make_axes_locatable
import array as arr 
import pylab
import matplotlib as mpl
from matplotlib.colors import colorConverter
import matplotlib.gridspec as gridspec
from matplotlib.figure import Figure 
from mpl_toolkits.axisartist.axislines import Subplot

# %%
data = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\0.txt",encoding='utf-8').transpose()
points =len(list(zip(*data)))
range = 2000.0
km=1500.0
p=km/(range/points)
points
# Out:
# 500

# %%
data1 = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\5.txt",encoding='utf-8').transpose()
points1 =len(list(zip(*data1)))
p1=km/(range/points1)

# %%
data2 = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\23.txt",encoding='utf-8').transpose()
points2 =len(list(zip(*data2)))
p2=km/(range/points2)

# %%
data3 = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\1.5.txt",encoding='utf-8').transpose()
points3 =len(list(zip(*data3)))
p3=km/(range/points3)

# %%
data4 = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\2.txt",encoding='utf-8').transpose()
points4 =len(list(zip(*data4)))
p4=km/(range/points4)

# %%
data5 = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\1.txt",encoding='utf-8').transpose()
points5 =len(list(zip(*data5)))
p5=km/(range/points5)

# %%
data1 = np.genfromtxt(r"C:\\Users\\Маргарита\\CLionProjects\\untitled\\0.5.txt",encoding='utf-8').transpose()
points1 =len(list(zip(*data1)))
p1=km/(range/points1)

# %%
fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(8)

plt.subplot(3, 1, 1)
plt.imshow(data1,aspect='auto',origin='lower', extent=[0, 200, 0, 2])
plt.ylabel('x[высота], км') 
plt.title('Угол наклона 0,5°')
plt.colorbar(orientation='vertical')

plt.subplot(3, 1, 2)
plt.imshow(data5,aspect='auto',origin='lower', extent=[0, 200, 0, 2])
plt.ylabel('x[высота], км') 
plt.title('Угол наклона 1°')
plt.colorbar(orientation='vertical')


plt.tight_layout()
plt.subplot(3, 1, 3)
plt.imshow(data4,aspect='auto',origin='lower', extent=[0, 200, 0, 2])
plt.xlabel('z[дальность], км')
plt.ylabel('x[высота], км') 
plt.title('Угол наклона 2°')

plt.tight_layout()
plt.colorbar(orientation='vertical')


plt.show()
# Out:
# C:\Users\Маргарита\AppData\Local\Temp\ipykernel_13240\518303241.py:25: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
numbers = arr.array('d', data[:, round(p)])
numbers1 = arr.array('d', data1[:,round(p1)])
numbers2 = arr.array('d', data2[:,round(p2)])
numbers3 = arr.array('d', data3[:, round(p3)])
numbers4 = arr.array('d', data4[:, round(p4)])
numbers5 = arr.array('d', data5[:, round(p5)])

y=np.linspace(0,2000,2700)

 # Plotting both the curves simultaneously 
plt.figure(figsize=(7,10))
plt.plot(numbers, y, linestyle='-',linewidth='2',  label='0°' ) #0
plt.plot(numbers1, y, linestyle='-', linewidth='1.4', label='5°') 
plt.plot(numbers5, y, linestyle='-',linewidth='1.4',  label='11°') 
plt.plot(numbers4, y, linestyle='-', linewidth='1.5',color='black', label='15°') 
plt.plot(numbers3, y, linestyle=':', linewidth='1.4', label='18°')  
plt.plot(numbers2, y, linestyle=':', linewidth='1.4',color='b',  label='23°') 

plt.xlabel('|E|[В/м]')
plt.ylabel('Высота[м]')
plt.xlim(0,1.1)
plt.ylim(0,2000)
  
# Adding legend, which helps us recognize the curve according to it's color 
plt.legend(title='Угол наклона антенны') 
  
# To load the display window 
plt.show()
